# %%
#Project-ONE Housing Sales for 2019-2022

# %%
# Import dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\Angiescomputer\\Desktop\\Research\\2019-3cities.csv")
cities_dataframe = pd.read_csv("C:\\Users\\Angiescomputer\\Desktop\\Research\\2019-3cities.csv")
#3cities_dataframe.describe()

print(cities_dataframe)
# Out:
#                            Row Labels  Sum of 1/31/2019  Sum of 2/28/2019  \
# 0                          Austin, TX            328675            331510
# 1  Los Angeles-Long Beach-Anaheim, CA            668258            666101
# 2                        New York, NY            476721            477597
# 3                         Grand Total           1473654           1475208
#
#    Sum of 3/31/2019  Sum of 4/30/2019  Sum of 5/31/2019  Sum of 6/30/2019  \
# 0            333208            334118            334455            335130
# 1            664753            664321            665292            666314
# 2            478493            479494            480179            480376
# 3           1476454           1477933           1479926           1481820
#
#    Sum of 7/31/2019  Sum of 8/31/2019  Sum of 9/30/2019  Sum of 10/31/2019  \
# 0            335793            336666            338259             338243
# ...

# %%
>>> x = np.random.randint(low=1, high=11, size=50)
>>> y = x + np.random.randint(1, 5, size=x.size)
>>> data = np.column_stack((x, y))

>>> fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2,
...                                figsize=(8, 4))

>>> ax1.scatter(x=x, y=y, marker='o', c='r', edgecolor='b')
>>> ax1.set_title('3 Cities')
>>> ax1.set_xlabel('$x$')
>>> ax1.set_ylabel('$y$')

>>> ax2.hist(data, bins=np.arange(data.min(), data.max()),
...          label=('Cities', 'Costs'))
>>> ax2.legend(loc=(0.65, 0.8))
>>> ax2.set_title('Housing Costs for the US')
>>> ax2.yaxis.tick_right()

# %%
ips = sns.load_dataset('tips')
sns.lmplot(x ='total_bill', y ='tip', size = 2, aspect = 4, data = tips)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ANGIES~1\AppData\Local\Temp/ipykernel_6532/2158420514.py in <module>
#       1 ips = sns.load_dataset('tips')
# ----> 2 sns.lmplot(x ='total_bill', y ='tip', size = 2, aspect = 4, data = tips)
#
# NameError: name 'tips' is not defined

# %%
# create 2D array of City details
cities_dataframe = [['S1', 'M', 13, 123, 46],
        ['S2', 'M', 12, 134, 82],
        ['S3', 'F', 14, 114, 77],
        ['S4', 'M', 13, 136, 73],
        ['S5', 'F', 13, 107, 56],
        ['S6', 'F', 12, 121, 80],
        ['S7', 'M', 14, 113, 76],
        ['S8', 'F', 15, 123, 95],
        ['S9', 'F', 14, 112, 78],
        ['S10', 'M', 15, 100,60] ]
# creating the dataframe from the above data 
df = pd.DataFrame(cities_dataframe, columns = ['ID', 'New York','Los Angeles', 'Austin','New York'] )
df.hist()# create histogram for the numeric data(Age, Height,Marks)
plt.show() #displaying the plot

# %%
cities_dataframe.plot()
plt.title(" 3 Cities ")
plt.ylabel("Housing Costs")
# Out:
# Text(0, 0.5, 'Housing Costs')

# %%
# All the unemployment Rates for the years 2019,2020,2021,2022
#Files from the U.S Bureau of Labor Statistics was kinda hard to read
#so I isolated the info for all the States for the years 2018,2019,2020
#Giving us the Ratings for each State for each year. 
data = pd.read_csv("C:\\Users\\Angiescomputer\\Desktop\\Research\\Rates19_22.csv")
Rates1922_dataframe = pd.read_csv("C:\\Users\\Angiescomputer\\Desktop\\Research\\Rates19_22.csv")
#Rates1922_dataframe.describe()

print(Rates1922_dataframe)
# Out:
#                  States   2019   2020  2021  2022
# 0                Alabama  37.9   99.2  77.1   9.0
# 1                 Alaska  65.7   92.4  59.4  15.9
# 2                Arizona  58.3   73.0  48.7  10.0
# 3               Arkansas  41.6  123.3  88.4   9.4
# 4             California  49.4   82.6  64.9  15.9
# 5               Colorado  31.2   93.9  75.6  11.9
# 6            Connecticut  42.4   90.6  64.7  14.8
# 7               Delaware  44.4   95.1  80.1  13.9
# 8   District of Columbia  64.1   99.2  55.2  18.4
# 9                Florida  38.7   78.1  47.3  10.0
# 10               Georgia  43.3  144.5  69.3   9.5
# 11                Hawaii  29.1   65.9  43.1  12.6
# 12                 Idaho  35.6  110.6  73.5   8.5
# 13              Illinois  47.3   87.3  43.4  14.5
# 14               Indiana  39.5   62.0  51.3   6.9
# 15                  Iowa  47.3   68.2  39.4  10.5
# 16                Kansas  39.5   77.1  56.5   7.6
# 17              Kentucky  31.1  105.2  65.7  12.6
# ...

# %%
plt.style.use('fivethirtyeight')

x = np.linspace(0, 10)

# Fixing random state for reproducibility
np.random.seed(19680801)

fig, ax = plt.subplots()

ax.plot(x, np.sin(x) + x + np.random.randn(50))
ax.plot(x, np.sin(x) + 0.5 * x + np.random.randn(50))
ax.plot(x, np.sin(x) + 2 * x + np.random.randn(50))
ax.plot(x, np.sin(x) - 0.5 * x + np.random.randn(50))
ax.plot(x, np.sin(x) - 2 * x + np.random.randn(50))
ax.plot(x, np.sin(x) + np.random.randn(50))
ax.set_title("Growing Housing Prices")

plt.show()

# %%
#Graph comparing all 5 years 
Rates1922_dataframe.plot()
plt.title("Housing Market for all 50 states")
plt.ylabel("Housing Costs")
#The housing Markets of the US from 2019-2022
# Out:
# Text(0, 0.5, 'Housing Costs')

# %%
#creating 3 variables holding an array of 50 random values in the range 0 to 1
x=np.random.rand(50)  #represents the x axes coordinates
y=np.random.rand(50) #represents the y axes coordinates
sizes=np.random.rand(50) #represents the values and thus the size of the bubbles
plt.scatter(x,y,s=sizes*500)
plt.show()
