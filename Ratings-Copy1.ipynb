# %%
# Import dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
import pandas as pd

# %%
# All the unemployment Rates for the years 2018,2019,2020- 
#Files from the U.S Bureau of Labor Statistics was kinda hard to read
#so I isolated the info for all the States for the years 2018,2019,2020
#Giving us the Ratings for each State for each year. 
data = pd.read_csv("C:\\Users\\Angiescomputer\\Desktop\\Research\\Rates18_22.csv")
Rates1822_dataframe = pd.read_csv("C:\\Users\\Angiescomputer\\Desktop\\Research\\Rates18_22.csv")
#Rates1822_dataframe.describe()

print(Rates1822_dataframe)
# Out:
#                  States   2018  2019   2020  2021  2022
# 0                Alabama  47.0  37.9   99.2  77.1   9.0
# 1                 Alaska  65.3  65.7   92.4  59.4  15.9
# 2                Arizona  52.9  58.3   73.0  48.7  10.0
# 3               Arkansas  39.8  41.6  123.3  88.4   9.4
# 4             California  46.7  49.4   82.6  64.9  15.9
# 5               Colorado  33.3  31.2   93.9  75.6  11.9
# 6            Connecticut  43.0  42.4   90.6  64.7  14.8
# 7               Delaware  41.1  44.4   95.1  80.1  13.9
# 8   District of Columbia  62.0  64.1   99.2  55.2  18.4
# 9                Florida  40.4  38.7   78.1  47.3  10.0
# 10               Georgia  44.0  43.3  144.5  69.3   9.5
# 11                Hawaii  26.2  29.1   65.9  43.1  12.6
# 12                 Idaho  31.8  35.6  110.6  73.5   8.5
# 13              Illinois  48.0  47.3   87.3  43.4  14.5
# 14               Indiana  37.6  39.5   62.0  51.3   6.9
# 15                  Iowa  27.6  47.3   68.2  39.4  10.5
# ...

# %%
#Graph comparing all 5 years 
Rates1822_dataframe.plot()
#The housing Markets of the US from 2018-2022
# Out:
# <AxesSubplot:>

# %%
#Graph comparing all 5 years 
Rates1822_dataframe.plot.box()
#The housing Markets of the US from 2018-2022
# Out:
# <AxesSubplot:>

# %%
data = pd.read_csv("C:\\Users\\Angiescomputer\\Desktop\\Research2\\Average_housing Cost.csv")
housing_dataframe = pd.read_csv("C:\\Users\\Angiescomputer\\Desktop\\Research2\\Average_housing Cost.csv")
#housing_dataframe.describe()
print(housing_dataframe)
# Out:
#                            Row Labels  Sum of 1/31/2019  Sum of 12/31/2019  \
# 0                          Austin, TX            328675             338663
# 1  Los Angeles-Long Beach-Anaheim, CA            668258             676981
# 2                        New York, NY            476721             479314
# 3                         Grand Total           1473654            1494958
#
#    Sum of 1/31/2020  Sum of 12/31/2020  Sum of 1/31/2021  Sum of 12/31/2021  \
# 0            340922             381134            386839             550972
# 1            679968             738882            744037             871123
# 2            480342             511713            516552             575832
# 3           1501232            1631729           1647428            1997927
#
#    Sum of 1/31/2022
# 0            563908
# 1            881946
# 2            579787
# 3           2025641

# %%
#Graph comparing all 5 years 
housing_dataframe.plot()
#Average Housing Cost For Los Angeles , New York, Austin
# Out:
# <AxesSubplot:>
