# %%
datdata = pd.read_csv("C:\\Users\\Angiescomputer\\Desktop\\Research\\Rates19.csv")
BLS_dataframe = pd.read_csv("C:\\Users\\Angiescomputer\\Desktop\\Research\\Rates19.csv")
#Rates19_dataframe.describe()
print(BLS_dataframe)
# U.S Bureau of Labor Statisticsa = pd.read_csv("C:\\Users\\Angiescomputer\\Desktop\\Research\\Rates19.csv")
BLS_dataframe = pd.read_csv("C:\\Users\\Angiescomputer\\Desktop\\Research\\Rates19.csv")
#Rates19_dataframe.describe()
print(BLS_dataframe)
# U.S Bureau of Labor Statistics
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\ANGIES~1\AppData\Local\Temp/ipykernel_31336/516137836.py in <module>
# ----> 1 datdata = pd.read_csv("C:\\Users\\Angiescomputer\\Desktop\\Research\\Rates19.csv")
#       2 BLS_dataframe = pd.read_csv("C:\\Users\\Angiescomputer\\Desktop\\Research\\Rates19.csv")
#       3 #Rates19_dataframe.describe()
#       4 print(BLS_dataframe)
#       5 # U.S Bureau of Labor Statisticsa = pd.read_csv("C:\\Users\\Angiescomputer\\Desktop\\Research\\Rates19.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# Median Sales Prices OF Houses Sold For The United States- Years 2018-2022 Data is QUARTERLY

# %%
#Graph comparing all 5 years 
MSPU_dataframe.plot()
# Out:
# <AxesSubplot:>

# %%
fig_1=plt.figure(1,figsize=(6.4,4.8))

# %%
#Graph comparing all 5 years 
MSPU_dataframe.plot.box()
# Out:
# <AxesSubplot:>

# %%
axs =MSPU_dataframe.plot.area(figsize=(12, 4), subplots=True)

# %%
fig_1=plt.figure(1,figsize=(6.4,4.8))
